# %% [markdown]
# <a href="https://colab.research.google.com/github/kevshakes/deeplearningwithsamfaraday/blob/main/DL_with_Sam_Faraday_Lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning With Sam Faraday
# ## Lesson 3 Matplotlib - Pyplot

# %% [markdown]
# ## Intro to pyplot
# matplotlib.pyplot is a collection of functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc.
#
# In matplotlib.pyplot various states are preserved across function calls, so that it keeps track of things like the current figure and plotting area, and the plotting functions are directed to the current axes (please note that "axes" here and in most places in the documentation refers to the axes part of a figure and not the strict mathematical term for more than one axis).

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
import os

# %%
# let us use numpy to genarete some random numbers
import numpy as np

# %% [markdown]
# # Our First Graph

# %%
# Let us create our first graph
plt.plot([1, 2, 3, 4]) # some numbers
plt.ylabel('y / vertical label')
plt.xlabel('x / vertical label - We have learnt a lot with Sam Faraday')
plt.title("My frist graph with Matplotlib Pyplot - Isn't it cool")
plt.show()

# %% [markdown]
# # Our Second Graph

# %%
# evenly sampled time at 200ms intervals
time = np.arange(0., 5., 0.2)

# %%
print(time)
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %%
# r-- red dashes, bs blue squares and g^ green triangles
plt.plot(time, time, 'r--', time, time**2, 'bs', time, time**3, 'g^')
plt.show()

# %% [markdown]
# # Deep Learning With Sam Faraday
# Reviewing Lesson 2 with Answer

# %% [markdown]
# # Assignemt
#
# Homework 2
#
# Deadline: August 10th, 10 pm
#
# Based on Homework 1, please
#
# 1. Create a directory named my_images_directory
#
# 2. Download the zip file the link below to it
#
#
# https://storage.googleapis.com/tensorflow-1-public/course2/cats_and_dogs_filtered.zip
#
# 3. Unzip the file cats_and_dogs_filtered.zip using the line below
#
# from zipfile import ZipFile
#
# print("Unzipping files")
#     ZipFile('./images/cats_and_dogs_filtered.zip', 'r').extractall("./my_images_directory")
#
#
# 4.  Then visually analise it
#
# 5.  Delete all files whose extension is deferrent from *.jpg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import wget

# %%
# zipfile - Lib to zip and unzip files
from zipfile import ZipFile

# %%
# Get the Current Working Directory
os.getcwd()
# Out:
# '/content/my_images_directory'

# %%
# !mkdir my_images_directory

# %%
# !mkdir my_images_directory/images

# %%
os.chdir('/content/my_images_directory')

# %%
os.getcwd()
# Out:
# '/content/my_images_directory'

# %%
wget.download("https://storage.googleapis.com/tensorflow-1-public/course2/cats_and_dogs_filtered.zip",
                  out="./cats_and_dogs_filtered.zip")
# Out:
# './cats_and_dogs_filtered (1).zip'

# %%
ZipFile('./cats_and_dogs_filtered.zip', 'r').extractall("./images") # if so, download it to the folder imag

# %%
my_directory_list_var = os.listdir("./images/cats_and_dogs_filtered/train/cats")

# %%
# iterate through the list, printing each object name
counter = 0
for files in my_directory_list_var:
  counter += 1
  if counter > 10:
    break

  print(files)
# Out:
# cat.708.jpg
# cat.302.jpg
# cat.980.jpg
# cat.947.jpg
# cat.768.jpg
# cat.685.jpg
# cat.34.jpg
# cat.11.jpg
# cat.95.jpg
# cat.128.jpg

# %%
base_path = "./images/cats_and_dogs_filtered"
for(cur_dir, subdirs, files) in os.walk(base_path):
  for file in files:
    fname, fext = os.path.splitext(file)
    if fext.casefold() != ".jpg":
      os.remove(os.path.join(cur_dir, file))
      print(os.path.join(cur_dir, file))
# Out:
# ./images/cats_and_dogs_filtered/vectorize.py

# %% [markdown]
# # Showing Images

# %%
# Parameters for our graph; we'll output images in a 4x4 configuration
number_of_rows = 4
number_of_columns = 4

# %%
fig = plt.gcf()  # Set up matplotlib fig
fig.set_size_inches(number_of_columns * 4, number_of_rows * 4)  # then size it to fit 4x4 pics

# %%
train_cats_dir = ("./images/cats_and_dogs_filtered/train/cats")

train_dogs_dir = ("./images/cats_and_dogs_filtered/train/dogs")

# %%
# create 2 lists with cats and dogs names

train_cats_names = os.listdir(train_cats_dir)

train_dogs_names = os.listdir(train_dogs_dir)

# %%
# show the first 8 cats names
train_cats_names[0:8]
# Out:
# ['cat.708.jpg',
#  'cat.302.jpg',
#  'cat.980.jpg',
#  'cat.947.jpg',
#  'cat.768.jpg',
#  'cat.685.jpg',
#  'cat.34.jpg',
#  'cat.11.jpg']

# %%
# create a picture index
pic_index = 0

# %%
pic_index += 8 # rerun it from here, it will increment pic_index, show you can always see new pictures

# %%
my_directory_list_var[pic_index-8:pic_index]
# Out:
# ['cat.708.jpg',
#  'cat.302.jpg',
#  'cat.980.jpg',
#  'cat.947.jpg',
#  'cat.768.jpg',
#  'cat.685.jpg',
#  'cat.34.jpg',
#  'cat.11.jpg']

# %%
next_cat_pix = [os.path.join("./images/cats_and_dogs_filtered/train/cats", filename)  # create a list with 8 cats pictures
                  for filename in train_cats_names[pic_index-8:pic_index]]

# %%
# a different way to do the same thing

# train_cats_names is a list where we add the directory files names with the instructions
# train_cats_names = os.listdir(train_cats_dir)
# os.listdir (operating system.list directory - that's what it does, then add all the files names to the  train_cats_names list )
# as train_cats_names is a list, we can read passing the the first and the last item as parameters
# in order to read a different set of 8 pictures every time we run it code, we had previsouly incremented by 8 the variable pic_index
# then when get the file index pic_index-8 (we substract 8 in order to get the increment minus 8), that's the first item, then the last item,  pic_index with no increment
# so, the very fisrt time we run it, pic_index = 8
# so train_cats_names[pic_index-8:pic_index] =>  train_cats_names[8-8:8] => train_cats_names[0:8],
# so it will take from file 0 to file 8
# nxt time pci_index = 16, so train_cats_names[pic_index-8:pic_index] =>  train_cats_names[16-8:16] => train_cats_names[8:16]

# create an empty list
next_cat_pix=[]

for filename in train_dogs_names[pic_index-8:pic_index]:
  next_cat_pix.append(os.path.join("./images/cats_and_dogs_filtered/train/dogs", filename))

next_cat_pix
# Out:
# ['./images/cats_and_dogs_filtered/train/dogs/dog.742.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.542.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.90.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.503.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.556.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.236.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.247.jpg',
#  './images/cats_and_dogs_filtered/train/dogs/dog.822.jpg']

# %%
next_dog_pix = [os.path.join("./images/cats_and_dogs_filtered/train/dogs", filename)  # create a list with 8 dogs pictures
                  for filename in train_dogs_names[pic_index-8:pic_index]]

# %%
for i, img_path in enumerate(next_cat_pix+next_dog_pix):
    sp = plt.subplot(number_of_rows, number_of_columns, i + 1)  # Set up subplot; subplot indices start at 1
    sp.axis('Off')  # Don't show axes (or gridlines)

    img = mpimg.imread(img_path)
    plt.imshow(img)

plt.show()
